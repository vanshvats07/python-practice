# %%
names=["Krish","Jacob","Vansh",1,2,3,4,5]
print(names[3])
for i in range(len(names)):
    print(names[1])
# Out:
# 1
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob

# %%
fruits=["Apple","Banana","Mango","Grapes"]
for i in range(len(fruits)):
    print(fruits[i])

print(fruits)
fruits[2]="Pineapple"
print(fruits)
fruits.append("Watermelon")
print(fruits)
# Out:
# Apple
# Banana
# Mango
# Grapes
# ['Apple', 'Banana', 'Mango', 'Grapes']
# ['Apple', 'Banana', 'Pineapple', 'Grapes']
# ['Apple', 'Banana', 'Pineapple', 'Grapes', 'Watermelon']

# %%
fruits=["apple","banana","mango","grapes","kiwi"]
for i in range(len(fruits)):
    print(fruits[i])

print(fruits)
print(fruits[::1])
# Out:
# apple
# banana
# mango
# grapes
# kiwi
# ['apple', 'banana', 'mango', 'grapes', 'kiwi']
# ['apple', 'banana', 'mango', 'grapes', 'kiwi']

# %%
lst=[]
for i in range(10):
    if(i%2!=0):
        lst.append(i)
print(lst)
# Out:
# [1, 3, 5, 7, 9]

# %%
# Out:
# <class 'int'>

# %%
num=[1,2,3,4,5,6,7]
print(num)
num[1]=10
print(num)
num.append(12)
print(num)
van=["Vansh","Krish","Jacob","Daksh"]
print(van)
van.append("Rohan")
print(van)
van[3]="Rohit"
van[2]="Sangeeta"
van.append("Nave")
print(van)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# [1, 10, 3, 4, 5, 6, 7]
# [1, 10, 3, 4, 5, 6, 7, 12]
# ['Vansh', 'Krish', 'Jacob', 'Daksh']
# ['Vansh', 'Krish', 'Jacob', 'Daksh', 'Rohan']
# ['Vansh', 'Krish', 'Sangeeta', 'Rohit', 'Rohan', 'Naveen']
