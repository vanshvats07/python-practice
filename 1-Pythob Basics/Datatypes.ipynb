# %%
names=["Krish","Jacob","Vansh",1,2,3,4,5]
print(names[3])
for i in range(len(names)):
    print(names[1])
# Out:
# 1
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob
# Jacob

# %%
fruits=["apple","banana","mango","grapes","kiwi"]
fruits[1]="orange"
print(fruits[0:4])
fruits.append("santra")
print(fruits)
fruits.insert(1,"kela")
print(fruits)
fruits.pop()
print(fruits)
fruits.pop(2)
print(fruits)
fruits.sort()
print(fruits)
# Out:
# ['apple', 'orange', 'mango', 'grapes']
# ['apple', 'orange', 'mango', 'grapes', 'kiwi', 'santra']
# ['apple', 'kela', 'orange', 'mango', 'grapes', 'kiwi', 'santra']
# ['apple', 'kela', 'orange', 'mango', 'grapes', 'kiwi']
# ['apple', 'kela', 'mango', 'grapes', 'kiwi']
# ['apple', 'grapes', 'kela', 'kiwi', 'mango']

# %%
fruits=["apple","banana","mango","grapes","kiwi"]
for i in range(len(fruits)):
    print(fruits[i])

print(fruits)
print(fruits[::1])
# Out:
# apple
# banana
# mango
# grapes
# kiwi
# ['apple', 'banana', 'mango', 'grapes', 'kiwi']
# ['apple', 'banana', 'mango', 'grapes', 'kiwi']

# %%
lst=[]
for i in range(10):
    if(i%2!=0):
        lst.append(i)
print(lst)
# Out:
# [1, 3, 5, 7, 9]

# %%
# Out:
# <class 'int'>
