# %%
#Simple calculator
num1 = float(input("Enter first number"))
num2 = float(input("Enter second number"))
print("Addition of numbers is: ",num1+num2)
print("Subtraction of numbers is: ",num1-num2)
print("Multiplication of numbers is: ",num1*num2)
print("Division of numner is: ",num1/num2)
# Out:
# Addition of numbers is:  15.0
# Subtraction of numbers is:  9.0
# Multiplication of numbers is:  36.0
# Division of numner is:  4.0

# %%
a=100
print(a+3)
## declaring and assigning variables
name="Vansh"
age=18
height=5.10
is_student=True

print("age:",age)
print("name:",name)
print("height:",height)

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# 103
# age: 18
# name: Vansh
# height: 5.1
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Out:
# <class 'int'>
# 25
# <class 'str'>
